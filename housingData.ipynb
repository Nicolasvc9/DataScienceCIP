# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicolasvc9/DataScienceCIP/blob/main/housingData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
url="/content/drive/MyDrive/housingData.csv"
df=pd.read_csv(url)
print(df.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
datainfo=df.info()
print(datainfo)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB
# None

# %%
datainfo=df.describe()
print(datainfo)
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
df.hist("median_house_value")
# Out:
# array([[<Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
#Edf.hist()
df.hist(figsize=(20,8), edgecolor="black", bins=30)
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
import seaborn as sb
sb.scatterplot(x="latitude", y="longitude", data=df, hue="median_house_value", palette="coolwarm" )
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
sb.scatterplot(x="latitude", y="longitude", data=df[(df.median_income > 10)], hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
sb.scatterplot(x="latitude", y="longitude", data=df[(df.median_income > 10)], hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
dfN=df.dropna()
dfN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
dfN.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
print(dfN['ocean_proximity'].unique())
# Out:
# ['NEAR BAY' '<1H OCEAN' 'INLAND' 'NEAR OCEAN' 'ISLAND']

# %%
dfN["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: count, dtype: int64

# %%
# Dummies / One-Hot Encoding
dummies_ocean = pd.get_dummies(dfN["ocean_proximity"], dtype=int)

# Agregar las columnas dummies al DataFrame original
dfN = dfN.join(dummies_ocean)

# Mostrar las primeras filas del DataFrame actualizado
dfN.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# ...

# %%
dfN=dfN.drop("ocean_proximity", axis=1)
dfN.corr()
sb.set(rc={'figure.figsize': (15,8)})
sb.heatmap(dfN.corr(), annot=True, cmap="YlGnBu")
#dfN.corr()["median_house_value"].sort_values(ascending=False)
# Out:
# <Axes: >

# %%
x=dfN.drop("median_house_value", axis=1)
y=dfN["median_house_value"]

# %%
import sklearn
from sklearn.model_selection import train_test_split
X_entrena, X_prueba, Y_entrena, Y_prueba = train_test_split(x, y, test_size=.2)

# %%
X_prueba.shape
# Out:
# (4087, 13)

# %%
from sklearn.linear_model import LinearRegression

modelo=LinearRegression()
modelo.fit(X_entrena, Y_entrena)
# Out:
# LinearRegression()

# %%
comparativa = {"Prediccion": prediccion, "Valor Real": Y_prueba}
pd.DataFrame(comparativa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-10c9de304c9b> in <cell line: 0>()
# ----> 1 comparativa = {"Prediccion": prediccion, "Valor Real": Y_prueba}
#       2 pd.DataFrame(comparativa)
#
# NameError: name 'prediccion' is not defined

# %%
prediccion = modelo.predict(X_prueba)
print(prediccion)
# Out:
# [262086.30343629  90064.22507118 221478.53578727 ...  63635.8617348
#  181312.02378722 261117.61583461]

# %%
import sklearn.metrics as metrics
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y_prueba, prediccion)
mse
# Out:
# 4696940978.542623

# %%
# Evaluar el modelo con validación cruzada (métrica: error cuadratico)
from sklearn.model_selection import cross_val_score
scores = cross_val_score(modelo, x, y, cv=10, scoring='neg_mean_squared_error')
scores
# Out:
# array([-7.24502785e+09, -3.51492494e+09, -7.75863533e+09, -3.93664635e+09,
#        -6.55869575e+09, -4.87535622e+09, -2.74473835e+09, -8.32708418e+09,
#        -6.04058885e+09, -2.86360587e+09])

# %%
import numpy as np
rmse_scores = np.sqrt(-scores)
rmse_scores
# Out:
# array([85117.72934312, 59286.80239565, 88083.11604239, 62742.69957837,
#        80985.7749551 , 69823.75109584, 52390.25053211, 91252.8584722 ,
#        77721.22520377, 53512.67015962])

# %%
def mostrar_scores(scores):
  # MOSTRARIA EL PRIMER RESULTADO DE LA RAIS CUADRADA
  print("Puntajes de MSE en cada fold:", scores)
  # PROMEDIO
  print("Promedio de MSE:", np.mean(scores))
  # DESVIACION ESTANDAR
  print("Desviación estándar de MSE:", np.std(scores))

# %%
mostrar_scores(rmse_scores)
# Out:
# Puntajes de MSE en cada fold: [85117.72934312 59286.80239565 88083.11604239 62742.69957837
#  80985.7749551  69823.75109584 52390.25053211 91252.8584722
#  77721.22520377 53512.67015962]
# Promedio de MSE: 72091.68777781757
# Desviación estándar de MSE: 13759.321238818411

# %% [markdown]
# Modelo 1 REGRECION LINEAL
# Modelo 2 ARBOLES DE DESICION
# Modelo 3 BOSQUE ALEATORIO

# %%
from sklearn.tree import DecisionTreeRegressor
modelDecisionTree = DecisionTreeRegressor(random_state=42)
modelDecisionTree.fit(X_entrena, Y_entrena)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
mostrar_scores(scores=rmse_scores)
# Out:
# Puntajes de MSE en cada fold: [85117.72934312 59286.80239565 88083.11604239 62742.69957837
#  80985.7749551  69823.75109584 52390.25053211 91252.8584722
#  77721.22520377 53512.67015962]
# Promedio de MSE: 72091.68777781757
# Desviación estándar de MSE: 13759.321238818411

# %%
# Evaluar el modelo con validación cruzada (métrica: error cuadratico)
from sklearn.model_selection import cross_val_score
scores = cross_val_score(modelDecisionTree, x, y, cv=10, scoring='neg_mean_squared_error')
scores
# Out:
# array([-1.93202185e+10, -5.49628487e+09, -1.13285119e+10, -5.80476223e+09,
#        -7.18204918e+09, -6.88589657e+09, -4.51562567e+09, -1.20837905e+10,
#        -1.03616807e+10, -5.56581780e+09])

# %%
import numpy as np
rmse_scores = np.sqrt(-scores)
rmse_scores
# Out:
# array([138997.18866176,  74136.93321853, 106435.48211063,  76188.99019959,
#         84746.97148977,  82981.30256267,  67198.40525445, 109926.29592532,
#        101792.3412638 ,  74604.40874788])

# %%
mostrar_scores(rmse_scores)
# Out:
# Puntajes de MSE en cada fold: [138997.18866176  74136.93321853 106435.48211063  76188.99019959
#   84746.97148977  82981.30256267  67198.40525445 109926.29592532
#  101792.3412638   74604.40874788]
# Promedio de MSE: 91700.83194344032
# Desviación estándar de MSE: 21105.004412133527

# %% [markdown]
# RAMDOM FOREST (BOSQUES ALEATORIOS)

# %%
from sklearn.ensemble import RandomForestRegressor
modeloRandomF = RandomForestRegressor(n_estimators=100, random_state=42)
modeloRandomF.fit(X_entrena, Y_entrena)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Evaluar el modelo con validación cruzada (métrica: error cuadratico)
from sklearn.model_selection import cross_val_score
scores = cross_val_score(modeloRandomF, x, y, cv=10, scoring='neg_mean_squared_error')
scores
# Out:
# array([-1.14443007e+10, -2.39251726e+09, -4.95251413e+09, -3.61981068e+09,
#        -3.89158242e+09, -4.46391867e+09, -2.37197815e+09, -7.54996229e+09,
#        -6.55524233e+09, -2.98781291e+09])

# %%
import numpy as np
rmse_scores = np.sqrt(-scores)
rmse_scores
# Out:
# array([106978.03831001,  48913.36488785,  70374.10130739,  60164.86252583,
#         62382.54900055,  66812.56370299,  48702.95831385,  86890.51896028,
#         80964.45104981,  54660.89012302])

# %%
mostrar_scores(rmse_scores)
# Out:
# Puntajes de MSE en cada fold: [106978.03831001  48913.36488785  70374.10130739  60164.86252583
#   62382.54900055  66812.56370299  48702.95831385  86890.51896028
#   80964.45104981  54660.89012302]
# Promedio de MSE: 68684.42981815965
# Desviación estándar de MSE: 17476.07087805363

# %%
# Datos de evaluación
list_model = ['Linear Regression', 'DecisionTree', 'Random Forest']
list_mean = [68684.42981815965, 68684.42981815965, 68684.42981815965]
list_sd = [17476.07087805363, 17476.07087805363, 17476.07087805363]

# Agregamos una gráfica para comparar visualmente los resultados
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 5))
for i in range(3):
    plt.errorbar(i, list_mean[i], xerr=0, yerr=list_sd[i], fmt='o', linewidth=3)

plt.xticks([0, 1, 2], list_model)
plt.title("Evaluación de los modelos")
plt.ylim(0, 120000)
plt.grid(visible=True, which='major', color='#666666', linestyle='-')
plt.minorticks_on()
plt.grid(visible=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
plt.show()

# %%
import pandas as pd
import seaborn as sb

# %% [markdown]
# ARBOLES DE DECISION

# %%
sb.scatterplot(data=df, x="median_income", y="median_house_value")
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %% [markdown]
# # CLASE SABADO RESUMEN DE LA SEMANA CON NUEVOS MODELOS

# %% [markdown]
# Escalamos nuevamente los datos y austamos la variable X "X_entrena_escalado, X_prueba_escalado"

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_entrena_escalado = scaler.fit_transform(X_entrena)
X_prueba_escalado = scaler.fit_transform(X_prueba)

pd.DataFrame(X_entrena_escalado)
# Out:
#              0         1         2         3         4         5         6   \
# 0     -1.208609  0.793335  0.104377  0.642374  0.612453  0.318141  0.808881
# 1      1.231714 -1.381507 -0.686643 -0.748131 -0.644159 -0.519398 -0.684698
# 2     -1.198649  1.265721 -0.844848  0.570110  0.904466  0.844795  0.966931
# 3      1.296457 -1.334736  0.658092 -0.636283 -0.718359 -0.665593 -0.584599
# 4     -1.308214  0.858815  0.658092 -0.568162 -0.404805  0.141121 -0.444988
# ...         ...       ...       ...       ...       ...       ...       ...
# 16341  0.434874  0.087096 -0.686643  0.922685  1.823588 -0.677042 -0.666259
# 16342  1.206813 -1.273934 -1.082154 -0.471503 -0.562779 -0.638292 -0.684698
# 16343  0.937879 -0.988632 -2.031379  2.180169  2.168258  1.574009  2.052212
# 16344 -0.028290  0.325627 -1.161256  0.133765  0.148105  0.181633  0.155605
# 16345  0.285466 -0.151435  0.658092 -0.598540 -0.629798 -0.581047 -0.597770
#
# ...

# %% [markdown]
# Declaramos parametros para la validacion cruzada

# %%
from sklearn.model_selection import cross_val_score

# Parámetros para validación cruzada
cv = 10  # Número de particiones
scoring = 'neg_mean_squared_error'  # Métrica: MSE negativo

# %%
from sklearn.linear_model import LinearRegression

modeloN=LinearRegression()
modelo.fit(X_entrena_escalado, Y_entrena)
# Out:
# LinearRegression()

# %%
# Regresión Lineal
from sklearn.linear_model import LinearRegression

modelo_lineal = LinearRegression()

# Realizar validación cruzada
scores_lineal = cross_val_score(modelo_lineal, X_entrena_escalado, Y_entrena, cv=cv, scoring=scoring)

# Convertir los scores a valores positivos y calcular métricas
mse_lineal_cv = -scores_lineal  # Negar para obtener el MSE
promedio_lineal_cv = mse_lineal_cv.mean()

# Imprimir resultados
print("Validación Cruzada - Regresión Lineal:")
print(f"Errores cuadráticos medios (MSE): {mse_lineal_cv}")
print(f"MSE Promedio: {promedio_lineal_cv}")
# Out:
# Validación Cruzada - Regresión Lineal:
# Errores cuadráticos medios (MSE): [4.58547606e+09 4.90993083e+09 4.75163105e+09 5.03149465e+09
#  5.01873644e+09 4.39410862e+09 4.57731502e+09 4.70830828e+09
#  4.61593558e+09 4.89174381e+09]
# MSE Promedio: 4748468033.196582

# %%
from sklearn.tree import DecisionTreeRegressor
modelDecisionTree = DecisionTreeRegressor(random_state=42)
modelDecisionTree.fit(X_entrena_escalado, Y_entrena)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
# Árboles de Decisión
from sklearn.tree import DecisionTreeRegressor

modelo_arbol = DecisionTreeRegressor(random_state=42)

# Realizar validación cruzada
scores_arbol = cross_val_score(modelo_arbol, X_entrena_escalado, Y_entrena, cv=cv, scoring=scoring)

# Convertir los scores a valores positivos y calcular métricas
mse_arbol_cv = -scores_arbol  # Negar para obtener el MSE
promedio_arbol_cv = mse_arbol_cv.mean()

# Imprimir resultados
print("Validación Cruzada - Árboles de Decisión:")
print(f"Errores cuadráticos medios (MSE): {mse_arbol_cv}")
print(f"MSE Promedio: {promedio_arbol_cv}")
# Out:
# Validación Cruzada - Árboles de Decisión:
# Errores cuadráticos medios (MSE): [4.76125444e+09 5.20729103e+09 3.99901166e+09 4.78693683e+09
#  4.78314207e+09 4.60429881e+09 4.20206370e+09 4.62967521e+09
#  4.56004319e+09 4.73667018e+09]
# MSE Promedio: 4627038711.664731

# %%
from sklearn.ensemble import RandomForestRegressor
modeloRandomF = RandomForestRegressor(n_estimators=100, random_state=42)
modeloRandomF.fit(X_entrena_escalado, Y_entrena)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor

modelo_rf = RandomForestRegressor(n_estimators=100, random_state=42)

# Realizar validación cruzada
scores_rf = cross_val_score(modelo_rf, X_entrena_escalado, Y_entrena, cv=cv, scoring=scoring)

# Convertir los scores a valores positivos y calcular métricas
mse_rf_cv = -scores_rf  # Negar para obtener el MSE
promedio_rf_cv = mse_rf_cv.mean()

# Imprimir resultados
print("Validación Cruzada - Random Forest:")
print(f"Errores cuadráticos medios (MSE): {mse_rf_cv}")
print(f"MSE Promedio: {promedio_rf_cv}")
# Out:
# Validación Cruzada - Random Forest:
# Errores cuadráticos medios (MSE): [2.45179119e+09 2.51550046e+09 2.00866486e+09 2.63774572e+09
#  2.51999167e+09 2.31743841e+09 2.59587047e+09 2.42844383e+09
#  2.31072542e+09 2.39471939e+09]
# MSE Promedio: 2418089141.835801

# %%
# ---- Definición de Promedios y Desviaciones Estándar ----
promedio_lineal_cv = -scores_lineal.mean()  # Cambia a tu variable de resultados de regresión lineal
std_lineal_cv = scores_lineal.std()

promedio_arbol_cv = -scores_arbol.mean()  # Cambia a tu variable de resultados de Árbol de decisión
std_arbol_cv = scores_arbol.std()

promedio_rf_cv = -scores_rf.mean()  # Cambia a tu variable de resultados de Random Forest
std_rf_cv = scores_rf.std()

# %%
# ---- DATOS DE EVALUACIÓN ----
list_model = ['Linear Regression', 'DecisionTree', 'Random Forest']
list_mean = [promedio_lineal_cv, promedio_arbol_cv, promedio_rf_cv]  # Promedios de MSE de validación cruzada
list_sd = [std_lineal_cv, std_arbol_cv, std_rf_cv]  # Desviaciones estándar de MSE

# ---- GRÁFICA ----
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
for i in range(3):
    plt.errorbar(i, list_mean[i], xerr=0, yerr=list_sd[i], fmt='o', linewidth=3, label=list_model[i])

plt.xticks([0, 1, 2], list_model)
plt.title("Evaluación de Modelos (MSE y Desviación Estándar)")
plt.ylim(0, max(list_mean) + 2 * max(list_sd))  # Ajuste dinámico del límite superior del eje Y
plt.grid(visible=True, which='major', color='#666666', linestyle='-')
plt.minorticks_on()
plt.grid(visible=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
plt.ylabel("Mean Squared Error (MSE)")
plt.legend(title="Modelos")
plt.show()

# %%
modelo.score(x, y)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# -479229.8489283019

# %%
# RandomForest

#from sklearn.ensemble import RandomForestRegressor # This import is already done previously
from sklearn.model_selection import GridSearchCV


# Definimos los posibles parámetros
n_estimators = [3, 10, 30, 50, 80, 100]
min_samples_split = [2, 4, 6, 8]
max_depth = [2, 4, 6, 8, 10]

# Adjust parameter names to match RandomForestRegressor
params = {
    'n_estimators': n_estimators,
    'min_samples_split': min_samples_split,
    'max_depth': max_depth
}


#Aplicamos el método de ajuste
# Use modeloRandomF as the estimator instead of random_forest
grid_search = GridSearchCV(estimator=modeloRandomF, param_grid=params, cv=10, scoring='neg_mean_squared_error')
grid_search.fit(X_entrena, Y_entrena)
